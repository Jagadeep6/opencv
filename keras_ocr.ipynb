# %%
# !pip install -q keras-ocr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 KB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 52.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.2/619.2 KB 25.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 965.4/965.4 KB 33.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 2.2 MB/s eta 0:00:00
#   Building wheel for validators (setup.py) ... done

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
images = [
    keras_ocr.tools.read(img) for img in ['/content/image.png', '/content/image_3.png']
]

# %%
print(len(images))
# Out:
# 2

# %%
plt.figure(figsize= (20, 30))
plt.imshow(images[0])

# %%
prediction_groups = pipeline.recognize(images)
# Out:
# WARNING:tensorflow:6 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f66904a5a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 55s 55s/step
# 6/6 [==============================] - 36s 6s/step

# %%
print(prediction_groups)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-c6cc67a8ff6f> in <module>
#       1 fig, axs = plt.subplots(nrows = len(images), figsize = (20, 30))
#       2 for ax, image, predictions in zip(axs, images, prediction_groups):
# ----> 3   keras_ocr.tools.drawAnnotations(image=image, predictions = predictions, ax = ax)
#
# /usr/local/lib/python3.8/dist-packages/keras_ocr/tools.py in drawAnnotations(image, predictions, ax)
#     174             xy = box[0] / np.array([image.shape[1], image.shape[0]])
#     175             xy[1] = 1 - xy[1]
# --> 176             ax.annotate(
#     177                 text=text,
#     178                 xy=xy,
#
# TypeError: annotate() missing 1 required positional argument: 's'
